# %% [markdown]
# <a href="https://colab.research.google.com/github/CeorgeCao-HG/Reinforcement_Learning-RL/blob/main/PPO_Basic_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/ericyangyu/PPO-for-Beginners.git
# Out:
# Cloning into 'PPO-for-Beginners'...
# remote: Enumerating objects: 342, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 342 (delta 63), reused 59 (delta 59), pack-reused 266 (from 1)
# Receiving objects: 100% (342/342), 2.80 MiB | 10.21 MiB/s, done.
# Resolving deltas: 100% (211/211), done.

# %%
# %cd PPO/
# Out:
# [Errno 2] No such file or directory: 'PPO/'
# /content

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.7/163.7 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.2/323.2 kB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 99.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 61.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 70.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 119.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 80.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 113.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 5.0 MB/s eta 0:00:00
# ...

# %%
# !python main.py
#!python main.py --mode train
# Out:
# Streaming output truncated to the last 5000 lines.
# Average Episodic Length: 200.0
# Average Episodic Return: -1051.2
# Average Loss: -0.00034
# Timesteps So Far: 308000
# Iteration took: 1.69 secs
# ------------------------------------------------------
#
#
# -------------------- Iteration #141 --------------------
# Average Episodic Length: 200.0
# Average Episodic Return: -955.75
# Average Loss: -0.00224
# Timesteps So Far: 310200
# Iteration took: 2.54 secs
# ------------------------------------------------------
#
#
# -------------------- Iteration #142 --------------------
# Average Episodic Length: 200.0
# Average Episodic Return: -1080.06
# Average Loss: -0.00179
# Timesteps So Far: 312400
# Iteration took: 1.69 secs
# ------------------------------------------------------
#
#
# -------------------- Iteration #143 --------------------
# Average Episodic Length: 200.0
# Average Episodic Return: -1038.79
# Average Loss: -1e-04
# Timesteps So Far: 314600
# ...
